# %%
import pandas as pd

# %%
sales_data = r"C:\Users\Kaleb\Pandas-Challenge\HeroesOfPymoli\Resources\purchase_data.csv"
pyMoli_df = pd.read_csv(sales_data)
pyMoli_df.head()
#show data set
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
player_demographics = pyMoli_df.loc[:,["SN", "Age", "Gender"]]
#filter by SN, Age, and Gender

# %%
player_demographics.head()
# Out:
#               SN  Age Gender
# 0        Lisim78   20   Male
# 1    Lisovynya38   40   Male
# 2     Ithergue48   24   Male
# 3  Chamassasya86   24   Male
# 4      Iskosia90   23   Male

# %%
player_demographics = player_demographics.drop_duplicates()
player_demographics.head()
# drop duplicates for unique dataset
# Out:
#               SN  Age Gender
# 0        Lisim78   20   Male
# 1    Lisovynya38   40   Male
# 2     Ithergue48   24   Male
# 3  Chamassasya86   24   Male
# 4      Iskosia90   23   Male

# %%
#count dataset
player_count = player_demographics.count()[0]

# %%
player_count
# Out:
# 576

# %%
#find totals for purchase analysis
unique_items = len(pyMoli_df["Item ID"].unique())
average_price = pyMoli_df["Price"].mean()
total_purchases = pyMoli_df["Purchase ID"].count()
total_revenue = pyMoli_df["Price"].sum()
summary_table_purchases = pd.DataFrame({ "Number of Unique Items": [unique_items],
                                       "Average Price": [average_price],
                                       "Total Purchases": [total_purchases],
                                       "Total Revenue": [total_revenue],
                                       })
summary_table_purchases.head()
# Out:
#    Number of Unique Items  Average Price  Total Purchases  Total Revenue
# 0                     179       3.050987              780        2379.77

# %%
#gender count and percentage
gender_count = player_demographics["Gender"].value_counts()
gender_percentage = gender_count/player_count*100
gender_count
summary_table_gender = pd.DataFrame({ "Total Count": gender_count,
                                    "Percentage of Players": gender_percentage
                                    })
summary_table_gender.round(2)
summary_table_gender.head()
# Out:
#                        Total Count  Percentage of Players
# Male                           484              84.027778
# Female                          81              14.062500
# Other / Non-Disclosed           11               1.909722

# %%
#Age Demographics
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]


pyMoli_df["Age Group"] = pd.cut(pyMoli_df["Age"],age_bins, labels=group_names)
pyMoli_df


age_grouped = pyMoli_df.groupby("Age Group")


total_count_age = age_grouped["SN"].nunique()


percentage_by_age = (total_count_age/player_count) * 100


age_demographics = pd.DataFrame({"Percentage of Players": percentage_by_age, "Total Count": total_count_age})


age_demographics.index.name = None


age_demographics.style.format({"Percentage of Players":"{:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Percentage of Players</th>        <th class="col_heading level0 col1" >Total Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row0_col0" class="data row0 col0" >2.95</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row0_col1" class="data row0 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row1_col0" class="data row1 col0" >3.82</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row1_col1" class="data row1 col1" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row2_col0" class="data row2 col0" >18.58</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row2_col1" class="data row2 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row3_col0" class="data row3 col0" >44.79</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row3_col1" class="data row3 col1" >258</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row4_col0" class="data row4 col0" >13.37</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row4_col1" class="data row4 col1" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row5_col0" class="data row5 col0" >9.03</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row5_col1" class="data row5 col1" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row6_col0" class="data row6 col0" >5.38</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row6_col1" class="data row6 col1" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row7_col0" class="data row7 col0" >2.08</td>
#                         <td id="T_c3079fea_0905_11eb_8686_d46e0e11e4f5row7_col1" class="data row7 col1" >12</td>
#             </tr>
#     </tbody></table>

# %%
# Purchase Analysis (Age)
purchase_count_age = age_grouped["Purchase ID"].count()

avg_purchase_price_age = age_grouped["Price"].mean()

total_purchase_value = age_grouped["Price"].sum()

avg_total_purchase_per_person = total_purchase_value/player_count * 100

summary_table_age = pd.DataFrame({ "Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_price_age,
                                 "Total Purchase Value": total_purchase_value,
                                 "Average Total Purchase per Person": avg_total_purchase_per_person
                                 })
summary_table_age.head()
# Out:
#        Purchase Count  Average Purchase Price  Total Purchase Value  \
# <10                23                3.353478                 77.13
# 10-14              28                2.956429                 82.78
# 15-19             136                3.035956                412.89
# 20-24             365                3.052219               1114.06
# 25-29             101                2.900990                293.00
#
#        Average Total Purchase per Person
# <10                            13.390625
# 10-14                          14.371528
# 15-19                          71.682292
# 20-24                         193.413194
# 25-29                          50.868056

# %%
#Purchasing Analysis (Gender)
purchase_count = pyMoli_df.groupby(["Gender"]).count()["Price"]
avg_purchase_price = pyMoli_df.groupby(["Gender"]).mean()["Price"]
total_purchase_value = pyMoli_df.groupby(["Gender"]).sum()["Price"]
avg_total_person = (total_purchase_value / purchase_count * 100).round(2)

summary_table_purchasing = pd.DataFrame({"Purchase Count": purchase_count, "Average Purchase Price": avg_purchase_price, "Total Purchase Value": total_purchase_value, "Average Total per Person": avg_total_person})
summary_table_purchasing.head()
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Average Total per Person
# Gender
# Female                               361.94                    320.30
# Male                                1967.64                    301.79
# Other / Non-Disclosed                 50.19                    334.60

# %%
# Top spenders
spend_rank = pyMoli_df.groupby("SN")

purchase_count_rank = spend_rank["Purchase ID"].count()

avg_purchase_price_rank = spend_rank["Price"].mean()

total_purchase_price_rank = spend_rank["Price"].sum()

summary_table_rank = pd.DataFrame({"Purchase Count": purchase_count_rank,
                                  "Average_Purchase_Price": avg_purchase_price_rank,
                                  "Total Purchase Value": total_purchase_price_rank
                                  })
formatted_table = summary_table_rank.sort_values(["Total Purchase Value"], ascending=False).head()

formatted_table.head()
# Out:
#              Purchase Count  Average_Purchase_Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
# sort most popular item
items = pyMoli_df[["Item ID", "Item Name", "Price"]]
item_rank = items.groupby(["Item ID", "Item Name"])

purchase_count_item = item_rank["Price"].count()

item_Price = item_rank["Price"].count()
total_purchase_value = (item_rank["Price"].sum())
item_price = total_purchase_value/purchase_count_item

most_popular_item = pd.DataFrame({ "Purchase Count": purchase_count_item,
                                 "Item Price": item_price,
                                 "Total Purchase Value": total_purchase_value
                                 })
formatted_table_items = most_popular_item.sort_values(["Purchase Count"], ascending=False).head()

formatted_table_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
#
#                                                       Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                                 59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 145     Fiery Glass Crusader                                         41.22
# 132     Persuasion                                                   28.99
# 108     Extraction, Quickblade Of Trembling Hands                    31.77

# %%
# sort most profitable items
popular_formatted = most_popular_item.sort_values(["Total Purchase Value"],
                                                  ascending=False).head()
popular_formatted.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                                 59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 82      Nirvana                                                      44.10
# 145     Fiery Glass Crusader                                         41.22
# 103     Singed Scalpel                                               34.80
